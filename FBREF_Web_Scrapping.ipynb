# %%
from fake_useragent import UserAgent
from parsel import Selector
import requests
import time
from bs4 import BeautifulSoup
import json
import os
import re
import pandas as pd
import numpy as np

# %%
# Ignorar FutureWarnings
import warnings
import time
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %% [markdown]
# Função: get_user_agent
#
# Propósito:
#
# Gerar um cabeçalho HTTP com um agente de usuário (User-Agent) aleatório.
# Descrição:
#
# A função cria uma instância da classe UserAgent.
# Obtém um User-Agent aleatório usando o método random.
# Retorna um dicionário contendo o User-Agent gerado.
# Aplicação:
#
# Utilizada para fazer requisições HTTP com User-Agents diferentes, ajudando a evitar bloqueios por servidores que detectam acessos automatizados.

# %%
def get_user_agent():
    ua = UserAgent()
    header = {'User-Agent':str(ua.random)}

    return header

# %% [markdown]
# Função: verifica_e_le_json
#
#
# Propósito:
#
# Verificar a existência de um arquivo JSON e ler seu conteúdo, caso o arquivo exista. Salvamos a informação com o link do campeonato e os links dos times em um
# JSON local, para otimizar o processo
#
# Descrição:
#
# Verificação de Existência: A função verifica se o arquivo especificado pelo caminho existe.
# Leitura do Arquivo: Se o arquivo existir, ele é aberto em modo de leitura com codificação UTF-8.
# Carregamento do JSON: O conteúdo do arquivo é carregado em um dicionário usando a biblioteca json.
# Retorno dos Dados: Se o arquivo existe, os dados são retornados; caso contrário, a função retorna None.
#
#
# Aplicação:
#
# Útil para garantir que um arquivo JSON exista antes de tentar lê-lo, evitando erros de arquivo não encontrado e facilitando o manuseio seguro de dados JSON em aplicações.

# %%
def verifica_e_le_json(caminho_arquivo):
    if os.path.exists(caminho_arquivo):
        with open(caminho_arquivo, 'r', encoding='utf-8') as arquivo:
            dados = json.load(arquivo)
        return dados
    else:
        return None

# %% [markdown]
# Função: extract_number
#
# Propósito:
#
# Extrair o primeiro número de uma string que está dividida por barras ("/").
#
#
# Descrição:
#
# Divisão da String: A função divide a string de entrada pelos caracteres de barra ("/"), criando uma lista de partes.
# Busca por Números: Percorre cada parte da lista resultante.
# Verificação de Dígitos: Verifica se cada parte é composta apenas por dígitos.
# Retorno do Número: Retorna a primeira parte que contém apenas dígitos.
#
# Aplicação:
#
# Cada competição possui um código que fica no seu link (exemplo: https://fbref.com/en/comps/9/Premier-League-Stats  - O código da Premier League é 9). Usamos essa função para extrair esse código do link

# %%
def extract_number(text):
    # Divide a string pelos caracteres de barra ("/")
    text_parts = text.split('/')

    # Procura o número na lista resultante
    for part in text_parts:
        if part.isdigit():
            return part

# %% [markdown]
# Função: adjust_column
#
#
# Propósito:
#
# Ajustar os nomes das colunas de um DataFrame para simplificar e limpar os rótulos.
# Descrição:
#
# Combinação de Nomes de Colunas: Combina múltiplas camadas de nomes de colunas em uma única string para cada coluna, removendo espaços desnecessários.
# Inicialização da Lista de Novas Colunas: Cria uma lista vazia para armazenar os novos nomes de colunas.
# Iteração sobre as Colunas:
# Para cada nome de coluna combinado, verifica se contém a substring 'level_0'.
# Substituição Condicional:
# Se a coluna contém 'level_0', pega a última palavra do nome da coluna.
# Caso contrário, mantém o nome original da coluna.
# Armazenamento dos Novos Nomes: Adiciona cada novo nome de coluna à lista de novas colunas.
# Retorno das Novas Colunas: Retorna a lista com os nomes das colunas ajustados.
# Aplicação:
#
# Útil para limpar e simplificar os nomes de colunas de um DataFrame. As colunas das tabelas vem desformatadas, pelo fato de muitas delas estarem agrupadas em mais de uma célula. Aqui, fazemos o ajuste do nome das colunas.

# %%
def adjust_column(df):
    df_columns = [' '.join(col).strip() for col in df.columns]
    new_columns = []

    for col in df_columns:
        if 'level_0' in col:
            new_col = col.split()[-1]  # takes the last name
        else:
            new_col = col
        new_columns.append(new_col)
    return new_columns

# %% [markdown]
# Função: get_competition_coverage_all
#
#
# Propósito:
#
# Obter e salvar informações de cobertura de competições esportivas a partir do link do FBREF
#
# Descrição:
#
# Requisição da Página: Acessa a página de cobertura de competições do site FBref.
#
# Análise da Página: Utiliza BeautifulSoup para analisar o conteúdo HTML da página.
#
# Inicialização da Lista: Cria uma lista vazia para armazenar os dados das competições.
#
# Iteração sobre as Competições: Percorre todos os elementos <td> com o atributo data-stat='comp'.
#
# Extração de Informações: Para cada competição, extrai o nome, link, país, gênero, temporadas, e os anos de início e fim da cobertura.
#
# Formação do Link de Estatísticas: Gera o link para as estatísticas de cada competição.
#
# Criação do Dicionário: Cria um dicionário com as informações extraídas e calculadas.
#
# Armazenamento na Lista: Adiciona o dicionário à lista de competições.
#
# Salvamento dos Dados: Converte a lista de competições em JSON e salva em um arquivo.
#
# Retorno das Competições: Retorna a lista de competições com todas as informações coletadas.
#
#
# Aplicação:
#
# Esta função é útil para coletar, organizar e salvar dados de cobertura de competições esportivas do FBREF em um formato estruturado, facilitando análises e consultas posteriores.

# %%
def get_competition_coverage_all():

    access_link = 'https://fbref.com/en/about/coverage'
    data = requests.get(access_link,headers=get_user_agent())
    soup = BeautifulSoup(data.text, features="lxml")

    competitions = []

    for comp in soup.find_all('td', {'data-stat': 'comp'}):
        comp_link = comp.find('a')
        comp_text = comp_link.text.strip() if comp_link else ""
        comp_href = comp_link.get('href') if comp_link else ""
        maxseason =  comp.find_next_sibling('td', {'data-stat': 'maxseason'}).text.strip()
        stats_link = r'https://fbref.com/en/comps/' + extract_number(comp_href) + '/' + maxseason + '/' + maxseason + '-' + comp_text.replace(' ','-') + '-Stats'
            
        competition_data = {
            "comp": comp_text,
            "country": comp.find_next_sibling('td', {'data-stat': 'country'}).text.strip(),
            "hist_link": r'https://fbref.com' + comp_href,
            "stats_link":stats_link,
            "gender": comp.find_next_sibling('td', {'data-stat': 'gender'}).text.strip(),
            "seasons": comp.find_next_sibling('td', {'data-stat': 'Seasons'}).text.strip(),
            "minseason": comp.find_next_sibling('td', {'data-stat': 'minseason'}).text.strip(),
            "maxseason": maxseason
        }
            
        competitions.append(competition_data)

        #json_data = json.dumps(competitions, indent=4)

    with open('competitions_available.json', 'w') as json_file:
        json.dump(competitions, json_file)

    return competitions

# %%
    def return_team_links(gender='All'):

  
        json_data = verifica_e_le_json('C:\\Users\\dpsoe\\Downloads\\competitions_available.json') #get_competition_coverage_all()

        if json_data is None:
            json_data = get_competition_coverage_all()

        link_teams = {}
        num_req = 0

        if gender == 'All':
            list_gender = ['M','F']
        else:
            list_gender = list(gender)

        
        for data in json_data:

            
            if "2024" not in data["maxseason"]:
                continue

            if data["gender"] not in list_gender:
                continue

            if data["country"] == '':
                continue
            
            link = data["stats_link"]
            comp_name = data["comp"]
            gender = data["gender"]
            season = data["maxseason"]
            
            if num_req <= 20:
              data = requests.get(link, headers=get_user_agent())
              num_req += 1
            else:
              time.sleep(30)
              data = requests.get(link, headers=get_user_agent())
              num_req = 1
            
            soup =  BeautifulSoup(data.text,features="lxml")
            all_links = soup.find_all('td', {'data-stat': 'team'})
            
            list_links_teams = set()
            for links in all_links:
              all = links.find_all('a')
              for link in all:
                href = link.get('href')
                if href:
                  href_final = f'https://fbref.com' + href
                  list_links_teams.add(href_final)

                #Retorna os links dos times
            if gender not in link_teams.keys():
                link_teams[gender] = {}

            if comp_name not in link_teams[gender].keys():
                link_teams[gender][comp_name] = {}

            if season not in link_teams[gender][comp_name] .keys():
                link_teams[gender][comp_name][season] = list(list_links_teams)


        with open('link_teams_available.json', 'w') as json_file:
          json.dump(link_teams, json_file)

        return link_teams

# %%
teste = return_team_links(gender='All')

# %%
teste
# Out:
# {'M': {'FA Cup': {'2023-2024': []},
#   'FA Community Shield': {'2023-2024': []},
#   'EFL Cup': {'2023-2024': []},
#   'Copa del Rey': {'2023-2024': []},
#   'Supercopa de España': {'2023-2024': []},
#   'Coupe de France': {'2023-2024': []},
#   'Trophée des Champions': {'2023-2024': []},
#   'DFB-Pokal': {'2023-2024': []},
#   'DFL-Supercup': {'2023-2024': []},
#   'Coppa Italia': {'2023-2024': []},
#   'Supercoppa Italiana': {'2023-2024': []},
#   'Copa de la Liga Profesional': {'2024': ['https://fbref.com/en/squads/41c139b6/Velez-Sarsfield-Stats',
#     'https://fbref.com/en/squads/a4570206/Defensa-y-Justicia-Stats',
#     'https://fbref.com/en/squads/e2f19203/Instituto-Stats',
#     'https://fbref.com/en/squads/950a95f2/Gimnasia-y-Esgrima-LP-Stats',
#     'https://fbref.com/en/squads/9bf4eaf4/Newells-Old-Boys-Stats',
#     'https://fbref.com/en/squads/7765008b/Belgrano-Stats',
#     'https://fbref.com/en/squads/0e92bf17/Tigre-Stats',
#     'https://fbref.com/en/squads/b3d222b1/Deportivo-Riestra-Stats',
#     'https://fbref.com/en/squads/87a920fa/Rosario-Central-Stats',
#     'https://fbref.com/en/squads/40bb0ce9/Independiente-Stats',
#     'https://fbref.com/en/squads/df734df9/Estudiantes-LP-Stats',
#     'https://fbref.com/en/squads/ef99c78c/River-Plate-Stats',
#     'https://fbref.com/en/squads/8e20e13d/Racing-Club-Stats',
#     'https://fbref.com/en/squads/06c1606c/Banfield-Stats',
#     'https://fbref.com/en/squads/d01a653b/Argentinos-Juniors-Stats',
#     'https://fbref.com/en/squads/1d89634b/Barracas-Central-Stats',
#     'https://fbref.com/en/squads/66da6009/San-Lorenzo-Stats',
#     'https://fbref.com/en/squads/8a9d5afa/Independiente-Rivadavia-Stats',
#     'https://fbref.com/en/squads/e9ae80b7/Sarmiento-Stats',
#     'https://fbref.com/en/squads/795ca75e/Boca-Juniors-Stats',
#     'https://fbref.com/en/squads/3cbfa767/Platense-Stats',
#     'https://fbref.com/en/squads/42a1ab8b/Atletico-Tucuman-Stats',
#     'https://fbref.com/en/squads/ceda2145/Talleres-Stats',
#     'https://fbref.com/en/squads/1d3d37ae/Huracan-Stats',
#     'https://fbref.com/en/squads/5adc7e67/Union-Stats',
#     'https://fbref.com/en/squads/11b6dba8/Lanus-Stats',
#     'https://fbref.com/en/squads/9aa97c75/Central-Cordoba-SdE-Stats',
#     'https://fbref.com/en/squads/ac9a09b4/Godoy-Cruz-Stats']},
#   'Premier League': {'2023-2024': ['https://fbref.com/en/squads/1df6b87e/Sheffield-United-Stats',
#     'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#     'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#     'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#     'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#     'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#     'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#     'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#     'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#     'https://fbref.com/en/squads/943e8050/Burnley-Stats',
#     'https://fbref.com/en/squads/e297cd13/Luton-Town-Stats',
#     'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#     'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#     'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#     'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#     'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#     'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#     'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#     'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#     'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats']},
#   'Premier League 2': {'2023-2024': ['https://fbref.com/en/squads/740322cb/Reading-FC-U21-Stats',
#     'https://fbref.com/en/squads/6934984c/Aston-Villa-U21-Stats',
#     'https://fbref.com/en/squads/45bf2fb0/Arsenal-U21-Stats',
#     'https://fbref.com/en/squads/b4c2d36f/Blackburn-Rovers-U21-Stats',
#     'https://fbref.com/en/squads/74a5460e/Norwich-City-U21-Stats',
#     'https://fbref.com/en/squads/f7e88c47/Derby-County-U21-Stats',
#     'https://fbref.com/en/squads/411a29ac/Tottenham-Hotspur-U21-Stats',
#     'https://fbref.com/en/squads/fbb59f3a/Crystal-Palace-U21-Stats',
#     'https://fbref.com/en/squads/a8fbbb12/Wolverhampton-Wanderers-U21-Stats',
#     'https://fbref.com/en/squads/11b97082/Stoke-City-U21-Stats',
#     'https://fbref.com/en/squads/11da5cc7/Brighton-and-Hove-Albion-U21-Stats',
#     'https://fbref.com/en/squads/cc320bb0/Leicester-City-U21-Stats',
#     'https://fbref.com/en/squads/3cc6b990/Nottingham-Forest-U21-Stats',
#     'https://fbref.com/en/squads/179c33c7/Southampton-U21-Stats',
#     'https://fbref.com/en/squads/70483169/Sunderland-U21-Stats',
#     'https://fbref.com/en/squads/de731359/Chelsea-U21-Stats',
#     'https://fbref.com/en/squads/afa3c276/West-Ham-United-U21-Stats',
#     'https://fbref.com/en/squads/2e99ee2e/Everton-U21-Stats',
#     'https://fbref.com/en/squads/21823154/Leeds-United-U21-Stats',
#     'https://fbref.com/en/squads/b3bf8d09/Fulham-U21-Stats',
#     'https://fbref.com/en/squads/3ea79db4/Newcastle-United-U21-Stats',
#     'https://fbref.com/en/squads/1c067385/Manchester-United-U21-Stats',
#     'https://fbref.com/en/squads/d795b1d0/Middlesbrough-U21-Stats',
#     'https://fbref.com/en/squads/33861392/Liverpool-U21-Stats',
#     'https://fbref.com/en/squads/a324bb9a/Manchester-City-U21-Stats',
#     'https://fbref.com/en/squads/f1d886aa/West-Bromwich-Albion-U21-Stats']},
#   'La Liga': {'2023-2024': ['https://fbref.com/en/squads/9024a00a/Girona-Stats',
#     'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#     'https://fbref.com/en/squads/dcc91a7b/Valencia-Stats',
#     'https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#     'https://fbref.com/en/squads/2b390eca/Athletic-Club-Stats',
#     'https://fbref.com/en/squads/a0435291/Granada-Stats',
#     'https://fbref.com/en/squads/2a8183b3/Villarreal-Stats',
#     'https://fbref.com/en/squads/8d6fd021/Alaves-Stats',
#     'https://fbref.com/en/squads/fc536746/Real-Betis-Stats',
#     'https://fbref.com/en/squads/7848bd64/Getafe-Stats',
#     'https://fbref.com/en/squads/03c57e2b/Osasuna-Stats',
#     'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
#     'https://fbref.com/en/squads/e31d1cd9/Real-Sociedad-Stats',
#     'https://fbref.com/en/squads/ee7c297c/Cadiz-Stats',
#     'https://fbref.com/en/squads/2aa12281/Mallorca-Stats',
#     'https://fbref.com/en/squads/0049d422/Las-Palmas-Stats',
#     'https://fbref.com/en/squads/78ecf4bb/Almeria-Stats',
#     'https://fbref.com/en/squads/ad2be733/Sevilla-Stats',
#     'https://fbref.com/en/squads/f25da7fb/Celta-Vigo-Stats',
#     'https://fbref.com/en/squads/98e8af82/Rayo-Vallecano-Stats']},
#   'Ligue 1': {'2023-2024': ['https://fbref.com/en/squads/fd6114db/Monaco-Stats',
#     'https://fbref.com/en/squads/d2c87802/Lorient-Stats',
#     'https://fbref.com/en/squads/5c2737db/Le-Havre-Stats',
#     'https://fbref.com/en/squads/7fdd64e0/Reims-Stats',
#     'https://fbref.com/en/squads/d53c0b06/Lyon-Stats',
#     'https://fbref.com/en/squads/5725cc7b/Marseille-Stats',
#     'https://fbref.com/en/squads/281b0e73/Montpellier-Stats',
#     'https://fbref.com/en/squads/e2d8892c/Paris-Saint-Germain-Stats',
#     'https://fbref.com/en/squads/132ebc33/Nice-Stats',
#     'https://fbref.com/en/squads/fd4e0f7d/Lens-Stats',
#     'https://fbref.com/en/squads/c0d3eab4/Strasbourg-Stats',
#     'https://fbref.com/en/squads/f83960ae/Metz-Stats',
#     'https://fbref.com/en/squads/d9676424/Clermont-Foot-Stats',
#     'https://fbref.com/en/squads/cb188c0c/Lille-Stats',
#     'https://fbref.com/en/squads/b3072e00/Rennes-Stats',
#     'https://fbref.com/en/squads/3f8c4b5f/Toulouse-Stats',
#     'https://fbref.com/en/squads/fb08dbb3/Brest-Stats',
#     'https://fbref.com/en/squads/d7a486cd/Nantes-Stats']},
#   'Fußball-Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/4eaa11d7/Wolfsburg-Stats',
#     'https://fbref.com/en/squads/7a41008f/Union-Berlin-Stats',
#     'https://fbref.com/en/squads/054efa67/Bayern-Munich-Stats',
#     'https://fbref.com/en/squads/f0ac8ee6/Eintracht-Frankfurt-Stats',
#     'https://fbref.com/en/squads/033ea6b8/Hoffenheim-Stats',
#     'https://fbref.com/en/squads/b42c6323/Bochum-Stats',
#     'https://fbref.com/en/squads/a224b06a/Mainz-05-Stats',
#     'https://fbref.com/en/squads/acbb6a5b/RB-Leipzig-Stats',
#     'https://fbref.com/en/squads/add600ae/Dortmund-Stats',
#     'https://fbref.com/en/squads/a486e511/Freiburg-Stats',
#     'https://fbref.com/en/squads/c7a9f859/Bayer-Leverkusen-Stats',
#     'https://fbref.com/en/squads/bc357bf7/Koln-Stats',
#     'https://fbref.com/en/squads/18d9d2a7/Heidenheim-Stats',
#     'https://fbref.com/en/squads/598bc722/Stuttgart-Stats',
#     'https://fbref.com/en/squads/62add3bf/Werder-Bremen-Stats',
#     'https://fbref.com/en/squads/6a6967fc/Darmstadt-98-Stats',
#     'https://fbref.com/en/squads/32f3ee20/Monchengladbach-Stats',
#     'https://fbref.com/en/squads/0cdc4311/Augsburg-Stats']},
#   'A-Junioren Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/e5460de3/HSV-U19-Stats',
#     'https://fbref.com/en/squads/b58231eb/Klautern-U19-Stats',
#     'https://fbref.com/en/squads/0a2bc34c/Aachen-U19-Stats',
#     'https://fbref.com/en/squads/22c72f0b/St-Pauli-U19-Stats',
#     'https://fbref.com/en/squads/41d91186/Augsburg-U19-Stats',
#     'https://fbref.com/en/squads/d9f72365/Paderborn-07-U19-Stats',
#     'https://fbref.com/en/squads/f671e559/Meppen-U19-Stats',
#     'https://fbref.com/en/squads/01ef4cf1/Schalke-U19-Stats',
#     'https://fbref.com/en/squads/ff6f8fac/Wuppertal-U19-Stats',
#     'https://fbref.com/en/squads/e2bede9e/Dusseldorf-U19-Stats',
#     'https://fbref.com/en/squads/32f8bc7d/Ingolstadt-U19-Stats',
#     'https://fbref.com/en/squads/c880e925/KSC-U19-Stats',
#     'https://fbref.com/en/squads/299dbac7/Viktoria-U19-Stats',
#     'https://fbref.com/en/squads/6928de6d/Stuttgart-U19-Stats',
#     'https://fbref.com/en/squads/f1161405/Eintracht-Braunschweig-U19-Stats',
#     'https://fbref.com/en/squads/e16a2df0/1860-Munich-U19-Stats',
#     'https://fbref.com/en/squads/9e2f1945/Hansa-Rostock-U19-Stats',
#     'https://fbref.com/en/squads/9811e0ce/Bremen-U19-Stats',
#     'https://fbref.com/en/squads/c0cb86fe/Heidenheim-U19-Stats',
#     'https://fbref.com/en/squads/a95021a0/Sandhausen-U19-Stats',
#     'https://fbref.com/en/squads/6ed99f94/Nurnberg-U19-Stats',
#     'https://fbref.com/en/squads/ce4c058d/Mainz-U19-Stats',
#     'https://fbref.com/en/squads/d943111d/Dortmund-U19-Stats',
#     'https://fbref.com/en/squads/3c042330/Carl-Zeiss-Jena-U19-Stats',
#     'https://fbref.com/en/squads/d8495be3/Verl-U19-Stats',
#     'https://fbref.com/en/squads/a4a1c462/Bayern-U19-Stats',
#     'https://fbref.com/en/squads/df6f068b/Mgladbach-U19-Stats',
#     'https://fbref.com/en/squads/4f4b03ee/Wolfsburg-U19-Stats',
#     'https://fbref.com/en/squads/7cc68edf/Frankfurt-U19-Stats',
#     'https://fbref.com/en/squads/e850256c/Leipzig-U19-Stats',
#     'https://fbref.com/en/squads/7978e9a3/Koln-U19-Stats',
#     'https://fbref.com/en/squads/5af9af80/Furth-U19-Stats',
#     'https://fbref.com/en/squads/6eda181d/Duisburg-U19-Stats',
#     'https://fbref.com/en/squads/a036ca44/Osnabruck-U19-Stats',
#     'https://fbref.com/en/squads/b7f03da0/Hertha-U19-Stats',
#     'https://fbref.com/en/squads/5f618561/Union-U19-Stats',
#     'https://fbref.com/en/squads/0b55fe1b/Hannover-U19-Stats',
#     'https://fbref.com/en/squads/0d978394/Hoffenheim-U19-Stats',
#     'https://fbref.com/en/squads/5f0284ea/Bochum-U19-Stats',
#     'https://fbref.com/en/squads/e7f2df64/Dresden-U19-Stats',
#     'https://fbref.com/en/squads/6d14c1f7/Bielefeld-U19-Stats',
#     'https://fbref.com/en/squads/ecf53eea/Leverkusen-U19-Stats']},
#   'B-Junioren Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/6de8c4a5/Hoffenheim-U17-Stats',
#     'https://fbref.com/en/squads/519eb162/Rot-Weiss-Oberhausen-U17-Stats',
#     'https://fbref.com/en/squads/37a68655/Bochum-U17-Stats',
#     'https://fbref.com/en/squads/5d67715c/Dusseldorf-U17-Stats',
#     'https://fbref.com/en/squads/d9dd39c9/St-Pauli-U17-Stats',
#     'https://fbref.com/en/squads/bf9fcad9/Augsburg-U17-Stats',
#     'https://fbref.com/en/squads/f5369b66/Kaiserslautern-U17-Stats',
#     'https://fbref.com/en/squads/6c254a38/Dortmund-U17-Stats',
#     'https://fbref.com/en/squads/6df34a06/Paderborn-07-U17-Stats',
#     'https://fbref.com/en/squads/598306fb/Rot-Weiss-Essen-U17-Stats',
#     'https://fbref.com/en/squads/651b3d20/Hannover-U17-Stats',
#     'https://fbref.com/en/squads/a4988f5e/RB-Leipzig-U17-Stats',
#     'https://fbref.com/en/squads/05ebd479/MSV-Duisburg-U17-Stats',
#     'https://fbref.com/en/squads/aa20a5e5/Cottbus-U17-Stats',
#     'https://fbref.com/en/squads/4e32ce87/Dresden-U17-Stats',
#     'https://fbref.com/en/squads/5b499073/Koln-U17-Stats',
#     'https://fbref.com/en/squads/2640d362/KSC-U17-Stats',
#     'https://fbref.com/en/squads/aabd9798/Wolfsburg-U17-Stats',
#     'https://fbref.com/en/squads/94c74217/1860-Munich-U17-Stats',
#     'https://fbref.com/en/squads/8b10a09d/FC-Bayern-U17-Stats',
#     'https://fbref.com/en/squads/e76a63dd/Chemnitz-U17-Stats',
#     'https://fbref.com/en/squads/50eaaf29/Gladbach-U17-Stats',
#     'https://fbref.com/en/squads/b76f6237/Bielefeld-U17-Stats',
#     'https://fbref.com/en/squads/6569155a/Heidenheim-U17-Stats',
#     'https://fbref.com/en/squads/04bf3c00/Schalke-U17-Stats',
#     'https://fbref.com/en/squads/50e620c4/Union-U17-Stats',
#     'https://fbref.com/en/squads/32dd63ea/Freiburg-U17-Stats',
#     'https://fbref.com/en/squads/70f446ce/Holstein-Kiel-U17-Stats',
#     'https://fbref.com/en/squads/35596f77/Mainz-U17-Stats',
#     'https://fbref.com/en/squads/45a67fe8/Leverkusen-U17-Stats',
#     'https://fbref.com/en/squads/0d88491f/Viktoria-Berlin-U17-Stats',
#     'https://fbref.com/en/squads/81d83299/Hertha-U17-Stats',
#     'https://fbref.com/en/squads/391bc1a3/Ingolstadt-U17-Stats',
#     'https://fbref.com/en/squads/c149a178/VfB-Waltrop-U17-Stats',
#     'https://fbref.com/en/squads/8724a375/Nurnberg-U17-Stats',
#     'https://fbref.com/en/squads/f7ae58e6/Blumenthaler-U17-Stats',
#     'https://fbref.com/en/squads/f516c444/Stuttgart-U17-Stats',
#     'https://fbref.com/en/squads/b864db53/Viktoria-Koln-U17-Stats',
#     'https://fbref.com/en/squads/454cd859/Bremen-U17-Stats',
#     'https://fbref.com/en/squads/ef0e9ae7/Jahn-Regensburg-U17-Stats',
#     'https://fbref.com/en/squads/d84fbee9/HSV-U17-Stats',
#     'https://fbref.com/en/squads/34640cc6/Frankfurt-U17-Stats']},
#   'Serie A': {'2023-2024': ['https://fbref.com/en/squads/e2befd26/Sassuolo-Stats',
#     'https://fbref.com/en/squads/ffcbe334/Lecce-Stats',
#     'https://fbref.com/en/squads/7213da33/Lazio-Stats',
#     'https://fbref.com/en/squads/c5577084/Salernitana-Stats',
#     'https://fbref.com/en/squads/1d8099f8/Bologna-Stats',
#     'https://fbref.com/en/squads/6a7ad59d/Frosinone-Stats',
#     'https://fbref.com/en/squads/e0652b02/Juventus-Stats',
#     'https://fbref.com/en/squads/cf74a709/Roma-Stats',
#     'https://fbref.com/en/squads/421387cf/Fiorentina-Stats',
#     'https://fbref.com/en/squads/d48ad4ff/Napoli-Stats',
#     'https://fbref.com/en/squads/922493f3/Atalanta-Stats',
#     'https://fbref.com/en/squads/04eea015/Udinese-Stats',
#     'https://fbref.com/en/squads/c4260e09/Cagliari-Stats',
#     'https://fbref.com/en/squads/a3d88bd8/Empoli-Stats',
#     'https://fbref.com/en/squads/d609edc0/Internazionale-Stats',
#     'https://fbref.com/en/squads/0e72edf2/Hellas-Verona-Stats',
#     'https://fbref.com/en/squads/105360fe/Torino-Stats',
#     'https://fbref.com/en/squads/658bf2de/Genoa-Stats',
#     'https://fbref.com/en/squads/21680aa4/Monza-Stats',
#     'https://fbref.com/en/squads/dc56fe14/Milan-Stats']},
#   'Argentine Primera División': {'2024': ['https://fbref.com/en/squads/41c139b6/Velez-Sarsfield-Stats',
#     'https://fbref.com/en/squads/a4570206/Defensa-y-Justicia-Stats',
#     'https://fbref.com/en/squads/e2f19203/Instituto-Stats',
#     'https://fbref.com/en/squads/950a95f2/Gimnasia-y-Esgrima-LP-Stats',
#     'https://fbref.com/en/squads/9bf4eaf4/Newells-Old-Boys-Stats',
#     'https://fbref.com/en/squads/7765008b/Belgrano-Stats',
#     'https://fbref.com/en/squads/0e92bf17/Tigre-Stats',
#     'https://fbref.com/en/squads/b3d222b1/Deportivo-Riestra-Stats',
#     'https://fbref.com/en/squads/df734df9/Estudiantes-LP-Stats',
#     'https://fbref.com/en/squads/87a920fa/Rosario-Central-Stats',
#     'https://fbref.com/en/squads/40bb0ce9/Independiente-Stats',
#     'https://fbref.com/en/squads/ef99c78c/River-Plate-Stats',
#     'https://fbref.com/en/squads/8e20e13d/Racing-Club-Stats',
#     'https://fbref.com/en/squads/06c1606c/Banfield-Stats',
#     'https://fbref.com/en/squads/d01a653b/Argentinos-Juniors-Stats',
#     'https://fbref.com/en/squads/1d89634b/Barracas-Central-Stats',
#     'https://fbref.com/en/squads/66da6009/San-Lorenzo-Stats',
#     'https://fbref.com/en/squads/8a9d5afa/Independiente-Rivadavia-Stats',
#     'https://fbref.com/en/squads/e9ae80b7/Sarmiento-Stats',
#     'https://fbref.com/en/squads/795ca75e/Boca-Juniors-Stats',
#     'https://fbref.com/en/squads/3cbfa767/Platense-Stats',
#     'https://fbref.com/en/squads/42a1ab8b/Atletico-Tucuman-Stats',
#     'https://fbref.com/en/squads/1d3d37ae/Huracan-Stats',
#     'https://fbref.com/en/squads/ceda2145/Talleres-Stats',
#     'https://fbref.com/en/squads/5adc7e67/Union-Stats',
#     'https://fbref.com/en/squads/11b6dba8/Lanus-Stats',
#     'https://fbref.com/en/squads/9aa97c75/Central-Cordoba-SdE-Stats',
#     'https://fbref.com/en/squads/ac9a09b4/Godoy-Cruz-Stats']},
#   'A-League Men': {'2023-2024': ['https://fbref.com/en/squads/af4ccd77/Western-United-Stats',
#     'https://fbref.com/en/squads/f951d655/Macarthur-FC-Stats',
#     'https://fbref.com/en/squads/fbcd7d37/Melbourne-Victory-Stats',
#     'https://fbref.com/en/squads/38e60d08/Western-Sydney-Wanderers-Stats',
#     'https://fbref.com/en/squads/81134e0b/Wellington-Phoenix-Stats',
#     'https://fbref.com/en/squads/f2b23808/Perth-Glory-Stats',
#     'https://fbref.com/en/squads/2466c132/Sydney-FC-Stats',
#     'https://fbref.com/en/squads/31553c94/Melbourne-City-Stats',
#     'https://fbref.com/en/squads/f9e3296b/Newcastle-Jets-Stats',
#     'https://fbref.com/en/squads/605aca82/Central-Coast-Mariners-Stats',
#     'https://fbref.com/en/squads/3efc42c3/Brisbane-Roar-Stats',
#     'https://fbref.com/en/squads/a4302376/Adelaide-United-Stats']},
#   'Austrian Football Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/d20821dd/LASK-Stats',
#     'https://fbref.com/en/squads/c63dd2d5/WSG-Tirol-Stats',
#     'https://fbref.com/en/squads/80beba99/Rheindorf-Altach-Stats',
#     'https://fbref.com/en/squads/3f4fe568/Sturm-Graz-Stats',
#     'https://fbref.com/en/squads/b43d1132/SC-Austria-Lustenau-Stats',
#     'https://fbref.com/en/squads/7030fffd/SK-Austria-Klagenfurt-Stats',
#     'https://fbref.com/en/squads/f6d9c820/Hartberg-Stats',
#     'https://fbref.com/en/squads/ee0bccc5/Austria-Wien-Stats',
#     'https://fbref.com/en/squads/924cd17a/Blau-Weiss-Linz-Stats',
#     'https://fbref.com/en/squads/912e4c40/Rapid-Wien-Stats',
#     'https://fbref.com/en/squads/50f2a074/Red-Bull-Salzburg-Stats',
#     'https://fbref.com/en/squads/426658a6/Wolfsberger-AC-Stats']},
#   'Belgian Pro League': {'2023-2024': ['https://fbref.com/en/squads/1e972a99/Genk-Stats',
#     'https://fbref.com/en/squads/5809ddc3/Eupen-Stats',
#     'https://fbref.com/en/squads/e14f61a5/Union-SG-Stats',
#     'https://fbref.com/en/squads/08ad393c/Anderlecht-Stats',
#     'https://fbref.com/en/squads/57b6cfb8/Westerlo-Stats',
#     'https://fbref.com/en/squads/140e320a/Charleroi-Stats',
#     'https://fbref.com/en/squads/27e981a3/OH-Leuven-Stats',
#     'https://fbref.com/en/squads/f1e6c5f1/Club-Brugge-Stats',
#     'https://fbref.com/en/squads/09f00144/Mechelen-Stats',
#     'https://fbref.com/en/squads/80328a1e/Sint-Truiden-Stats',
#     'https://fbref.com/en/squads/77193015/Kortrijk-Stats',
#     'https://fbref.com/en/squads/c2e6b53b/Antwerp-Stats',
#     'https://fbref.com/en/squads/33c6b26e/Standard-Liege-Stats',
#     'https://fbref.com/en/squads/e423ea45/RWD-Molenbeek-Stats',
#     'https://fbref.com/en/squads/51e5a603/Gent-Stats',
#     'https://fbref.com/en/squads/e8d2adc4/Cercle-Brugge-Stats']},
#   'División de Fútbol Profesional': {'2024': ['https://fbref.com/en/squads/8d727f54/Always-Ready-Stats',
#     'https://fbref.com/en/squads/40d8842e/Blooming-Stats',
#     'https://fbref.com/en/squads/92adb2d6/Guabira-Stats',
#     'https://fbref.com/en/squads/a2ff197a/San-Antonio-Bulo-Bulo-Stats',
#     'https://fbref.com/en/squads/1e567884/GV-San-Jose-Stats',
#     'https://fbref.com/en/squads/6dcc14bf/The-Strongest-Stats',
#     'https://fbref.com/en/squads/e0bd5e35/Real-Tomayapo-Stats',
#     'https://fbref.com/en/squads/ad63267c/Nacional-Potosi-Stats',
#     'https://fbref.com/en/squads/e69cb5b6/Bolivar-Stats',
#     'https://fbref.com/en/squads/c0dcc2ac/Aurora-Stats',
#     'https://fbref.com/en/squads/8211ee59/Independiente-Petrolero-Stats',
#     'https://fbref.com/en/squads/a58173b2/Jorge-Wilstermann-Stats',
#     'https://fbref.com/en/squads/309ef279/FC-Universitario-Stats',
#     'https://fbref.com/en/squads/bdc20e84/Oriente-Petrolero-Stats',
#     'https://fbref.com/en/squads/ee5932d2/Royal-Pari-Stats',
#     'https://fbref.com/en/squads/f9667ebb/Real-Santa-Cruz-Stats']},
#   'Campeonato Brasileiro Série A': {'2024': ['https://fbref.com/en/squads/abdce579/Palmeiras-Stats',
#     'https://fbref.com/en/squads/d5ae3703/Gremio-Stats',
#     'https://fbref.com/en/squads/639950ae/Flamengo-Stats',
#     'https://fbref.com/en/squads/f0e6fb14/Cuiaba-Stats',
#     'https://fbref.com/en/squads/32d508ca/Atletico-Goianiense-Stats',
#     'https://fbref.com/en/squads/f98930d1/Red-Bull-Bragantino-Stats',
#     'https://fbref.com/en/squads/03ff5eeb/Cruzeiro-Stats',
#     'https://fbref.com/en/squads/d9fdd9d9/Botafogo-RJ-Stats',
#     'https://fbref.com/en/squads/84d9701c/Fluminense-Stats',
#     'https://fbref.com/en/squads/157b7fee/Bahia-Stats',
#     'https://fbref.com/en/squads/3f7595bb/Criciuma-Stats',
#     'https://fbref.com/en/squads/33f95fe0/Vitoria-Stats',
#     'https://fbref.com/en/squads/422bb734/Atletico-Mineiro-Stats',
#     'https://fbref.com/en/squads/a9d0ab0e/Fortaleza-Stats',
#     'https://fbref.com/en/squads/83f55dbe/Vasco-da-Gama-Stats',
#     'https://fbref.com/en/squads/bf4acd28/Corinthians-Stats',
#     'https://fbref.com/en/squads/5f232eb1/Sao-Paulo-Stats',
#     'https://fbref.com/en/squads/2091c619/Athletico-Paranaense-Stats',
#     'https://fbref.com/en/squads/d081b697/Juventude-Stats',
#     'https://fbref.com/en/squads/6f7e1f03/Internacional-Stats']},
#   'First Professional Football League': {'2023-2024': ['https://fbref.com/en/squads/21b98152/Lokomotiv-Sofia-Stats',
#     'https://fbref.com/en/squads/eac36dde/CSKA-1948-Stats',
#     'https://fbref.com/en/squads/87c3235f/Botev-Vratsa-Stats',
#     'https://fbref.com/en/squads/cbd9f3f6/Etar-Stats',
#     'https://fbref.com/en/squads/e0242ef1/Lokomotiv-Plovdiv-Stats',
#     'https://fbref.com/en/squads/50facccf/Pirin-Blagoevgrad-Stats',
#     'https://fbref.com/en/squads/488c6ba1/Ludogorets-Razgrad-Stats',
#     'https://fbref.com/en/squads/66906381/Arda-Stats',
#     'https://fbref.com/en/squads/e56e174a/Botev-Plovdiv-Stats',
#     'https://fbref.com/en/squads/ab7b2fe7/Beroe-Stats',
#     'https://fbref.com/en/squads/f66c03e0/PFC-Hebar-Pazardzhik-Stats',
#     'https://fbref.com/en/squads/7f023892/FK-Levski-2005-Stats',
#     'https://fbref.com/en/squads/3a7a27c6/Levski-Sofia-Stats',
#     'https://fbref.com/en/squads/b35f18af/Slavia-Sofia-Stats',
#     'https://fbref.com/en/squads/cbde2682/CSKA-Sofia-Stats',
#     'https://fbref.com/en/squads/f61e60c9/Cherno-More-Stats']},
#   'Canadian Premier League': {'2024': ['https://fbref.com/en/squads/8514c671/Forge-FC-Stats',
#     'https://fbref.com/en/squads/b0e76152/Cavalry-FC-Stats',
#     'https://fbref.com/en/squads/1ba245db/Vancouver-FC-Stats',
#     'https://fbref.com/en/squads/47eaa5a1/HFX-Wanderers-Stats',
#     'https://fbref.com/en/squads/ccdb10ba/Atletico-Ottawa-Stats',
#     'https://fbref.com/en/squads/e084d752/Pacific-FC-Stats',
#     'https://fbref.com/en/squads/cc00daff/Valour-FC-Stats',
#     'https://fbref.com/en/squads/6ec65eed/York-United-Stats']},
#   'Chilean Primera División': {'2024': ['https://fbref.com/en/squads/f052bc76/La-Calera-Stats',
#     'https://fbref.com/en/squads/13b57ed6/Audax-Italiano-Stats',
#     'https://fbref.com/en/squads/d4a88ef6/Universidad-de-Chile-Stats',
#     'https://fbref.com/en/squads/ed392b02/Cobresal-Stats',
#     'https://fbref.com/en/squads/69a3f4b2/Cobreloa-Stats',
#     'https://fbref.com/en/squads/85c3a70f/Coquimbo-Unido-Stats',
#     'https://fbref.com/en/squads/40d7a591/Deportes-Copiapo-Stats',
#     'https://fbref.com/en/squads/3e3fbf36/Universidad-Catolica-Stats',
#     'https://fbref.com/en/squads/9c1af4fe/Nublense-Stats',
#     'https://fbref.com/en/squads/2ff539f3/Colo-Colo-Stats',
#     'https://fbref.com/en/squads/def379c5/Union-Espanola-Stats',
#     'https://fbref.com/en/squads/5049d576/OHiggins-Stats',
#     'https://fbref.com/en/squads/e3816a4b/Huachipato-Stats',
#     'https://fbref.com/en/squads/81a74688/Everton-Stats',
#     'https://fbref.com/en/squads/fccf2756/Palestino-Stats',
#     'https://fbref.com/en/squads/c1d9f388/Deportes-Iquique-Stats']},
#   'Chinese Football Association Super League': {'2024': ['https://fbref.com/en/squads/c48512d3/Shanghai-SIPG-Stats',
#     'https://fbref.com/en/squads/d721b332/Shandong-Luneng-Taishan-Stats',
#     'https://fbref.com/en/squads/b037fc40/Henan-Stats',
#     'https://fbref.com/en/squads/8d9bcfa3/Zhejiang-Energy-Greentown-Stats',
#     'https://fbref.com/en/squads/1ead990f/Wuhan-Three-Towns-FC-Stats',
#     'https://fbref.com/en/squads/fdef5e66/Qingdao-Jonoon-Stats',
#     'https://fbref.com/en/squads/8ab37ab8/Beijing-Sinobo-Guoan-Stats',
#     'https://fbref.com/en/squads/7a10d7e2/Sichuan-Stats',
#     'https://fbref.com/en/squads/08166b70/Meizhou-Hakka-Stats',
#     'https://fbref.com/en/squads/42dff5fb/Tianjin-Jinmen-Tiger-Stats',
#     'https://fbref.com/en/squads/d87e75be/Qingdao-Kangtaiyuan-FC-Stats',
#     'https://fbref.com/en/squads/b919ea48/Nantong-Zhiyun-FC-Stats',
#     'https://fbref.com/en/squads/693f4682/Changchun-Yatai-Stats',
#     'https://fbref.com/en/squads/8385b101/Shanghai-Shenhua-Stats',
#     'https://fbref.com/en/squads/abbeb68a/Chengdu-Better-City-FC-Stats',
#     'https://fbref.com/en/squads/0e2ae537/Shijiazhuang-Ever-Bright-Stats']},
#   'Categoría Primera A': {'2024': ['https://fbref.com/en/squads/af8be55a/Once-Caldas-Stats',
#     'https://fbref.com/en/squads/6466f662/Rionegro-Stats',
#     'https://fbref.com/en/squads/70068101/Independiente-Stats',
#     'https://fbref.com/en/squads/72f9f06e/Pasto-Stats',
#     'https://fbref.com/en/squads/c6f65a93/CD-America-Stats',
#     'https://fbref.com/en/squads/a7854d10/Santa-Fe-Stats',
#     'https://fbref.com/en/squads/e1d2289f/Fortaleza-FC-Stats',
#     'https://fbref.com/en/squads/6045b728/Deportivo-Pereira-Stats',
#     'https://fbref.com/en/squads/b075ba2a/Boyaca-Patriot-Stats',
#     'https://fbref.com/en/squads/ffc8a1d6/Alianza-Stats',
#     'https://fbref.com/en/squads/f46a80fc/Boyaca-Chico-Stats',
#     'https://fbref.com/en/squads/16b2606a/La-Equidad-Stats',
#     'https://fbref.com/en/squads/b281fa3b/Junior-Stats',
#     'https://fbref.com/en/squads/9c4c0cc1/Tolima-Stats',
#     'https://fbref.com/en/squads/e0b973a6/Atletico-Nacional-Stats',
#     'https://fbref.com/en/squads/024b201d/Jaguares-Stats',
#     'https://fbref.com/en/squads/67cdee3a/Envigado-Stats',
#     'https://fbref.com/en/squads/9b9a8c22/CA-Bucaramanga-Stats',
#     'https://fbref.com/en/squads/47538775/AD-Cali-Stats',
#     'https://fbref.com/en/squads/4c319052/Millonarios-Stats']},
#   'Croatian Football League': {'2023-2024': ['https://fbref.com/en/squads/edd0d381/Dinamo-Zagreb-Stats',
#     'https://fbref.com/en/squads/ea115eb3/Lokomotiva-Stats',
#     'https://fbref.com/en/squads/a021ec1b/Rudes-Stats',
#     'https://fbref.com/en/squads/c5727287/Varazdin-Stats',
#     'https://fbref.com/en/squads/4faa6f09/Gorica-Stats',
#     'https://fbref.com/en/squads/6777e16d/Hajduk-Split-Stats',
#     'https://fbref.com/en/squads/7a798c4b/Slaven-Belupo-Stats',
#     'https://fbref.com/en/squads/f49c0f7a/Istra-1961-Stats',
#     'https://fbref.com/en/squads/25dbe099/Rijeka-Stats',
#     'https://fbref.com/en/squads/57d14db5/Osijek-Stats']},
#   'Czech First League': {'2023-2024': ['https://fbref.com/en/squads/8424bb18/Jablonec-Stats',
#     'https://fbref.com/en/squads/f6a3b786/Hradec-Kralove-Stats',
#     'https://fbref.com/en/squads/d9097887/Fastav-Zlin-Stats',
#     'https://fbref.com/en/squads/5c50c933/Karvina-Stats',
#     'https://fbref.com/en/squads/06183666/Teplice-Stats',
#     'https://fbref.com/en/squads/38988e1a/Slovacko-Stats',
#     'https://fbref.com/en/squads/2c9bebcd/Slovan-Liberec-Stats',
#     'https://fbref.com/en/squads/ecb862be/Sparta-Prague-Stats',
#     'https://fbref.com/en/squads/70c92f33/Mlada-Boleslav-Stats',
#     'https://fbref.com/en/squads/02cd81bf/Viktoria-Plzen-Stats',
#     'https://fbref.com/en/squads/9c87251a/Banik-Ostrava-Stats',
#     'https://fbref.com/en/squads/d1eee0c9/Ceske-Budejov-Stats',
#     'https://fbref.com/en/squads/7d704744/FK-Pardubice-Stats',
#     'https://fbref.com/en/squads/111cbfb1/Slavia-Prague-Stats',
#     'https://fbref.com/en/squads/4a2ec81c/Bohemians-1905-Stats',
#     'https://fbref.com/en/squads/41c6978d/Sigma-Olomouc-Stats']},
#   'Superliga': {'2023-2024': ['https://fbref.com/en/squads/9ae196bd/AGF-Stats',
#     'https://fbref.com/en/squads/ede58dea/Viborg-Stats',
#     'https://fbref.com/en/squads/b0dd06cd/Silkeborg-Stats',
#     'https://fbref.com/en/squads/3c4fb635/Midtjylland-Stats',
#     'https://fbref.com/en/squads/713d0672/Lyngby-Stats',
#     'https://fbref.com/en/squads/1850e3f9/Nordsjaelland-Stats',
#     'https://fbref.com/en/squads/b064b765/Hvidovre-IF-Stats',
#     'https://fbref.com/en/squads/18050b20/FC-Copenhagen-Stats',
#     'https://fbref.com/en/squads/3f5150ef/Odense-Stats',
#     'https://fbref.com/en/squads/d06bc460/Randers-Stats',
#     'https://fbref.com/en/squads/ab75e049/Brondby-Stats',
#     'https://fbref.com/en/squads/cb89181d/Vejle-BK-Stats']},
#   'Liga Profesional Ecuador': {'2024': ['https://fbref.com/en/squads/66db845c/Delfin-Stats',
#     'https://fbref.com/en/squads/f9c314af/Imbabura-Sporting-Club-Stats',
#     'https://fbref.com/en/squads/c1f8ae36/CS-Emelec-Stats',
#     'https://fbref.com/en/squads/1284d3f9/LDU-de-Quito-Stats',
#     'https://fbref.com/en/squads/3af5df16/Tecnico-Univ-Stats',
#     'https://fbref.com/en/squads/99a46175/Deportivo-Cuenca-Stats',
#     'https://fbref.com/en/squads/0a14831e/El-Nacional-Stats',
#     'https://fbref.com/en/squads/01f5194d/Universidad-Catolica-Stats',
#     'https://fbref.com/en/squads/98637027/Orense-Stats',
#     'https://fbref.com/en/squads/8e8ff33e/Macara-Stats',
#     'https://fbref.com/en/squads/e3086cf4/Cumbaya-FC-Stats',
#     'https://fbref.com/en/squads/c33d7826/Libertad-FC-Stats',
#     'https://fbref.com/en/squads/c0cc20c3/SD-Aucas-Stats',
#     'https://fbref.com/en/squads/bbbdfd99/Mushuc-Runa-Stats',
#     'https://fbref.com/en/squads/990519b8/Independiente-del-Valle-Stats',
#     'https://fbref.com/en/squads/8c71aef1/Barcelona-Stats']},
#   'Veikkausliiga': {'2024': ['https://fbref.com/en/squads/acffac85/Ilves-Stats',
#     'https://fbref.com/en/squads/c889f292/SJK-Stats',
#     'https://fbref.com/en/squads/87f2fc2b/Haka-Stats',
#     'https://fbref.com/en/squads/5b8cfb05/Lahti-Stats',
#     'https://fbref.com/en/squads/e9fa2e8b/Inter-Turku-Stats',
#     'https://fbref.com/en/squads/8b63ce55/VPS-Stats',
#     'https://fbref.com/en/squads/de877ff8/IF-Gnistan-Stats',
#     'https://fbref.com/en/squads/e6f63673/KuPS-Stats',
#     'https://fbref.com/en/squads/7332ca44/Ekenas-IF-Stats',
#     'https://fbref.com/en/squads/c4e86b86/IFK-Mariehamn-Stats',
#     'https://fbref.com/en/squads/9fc6bb9a/AC-Oulu-Stats',
#     'https://fbref.com/en/squads/d7319d80/HJK-Helsinki-Stats']},
#   'Super League Greece': {'2023-2024': ['https://fbref.com/en/squads/80b1ef30/OFI-Crete-Stats',
#     'https://fbref.com/en/squads/f3a5726c/Panathinaikos-Stats',
#     'https://fbref.com/en/squads/d5348c80/AEK-Athens-Stats',
#     'https://fbref.com/en/squads/5a5e7874/PAOK-Stats',
#     'https://fbref.com/en/squads/6fc21c65/Panetolikos-Stats',
#     'https://fbref.com/en/squads/c9607f44/Atromitos-Stats',
#     'https://fbref.com/en/squads/6507d2b8/PAS-Giannina-Stats',
#     'https://fbref.com/en/squads/890cfc60/PAS-Lamia-Stats',
#     'https://fbref.com/en/squads/edddfa63/Aris-Stats',
#     'https://fbref.com/en/squads/d884c383/Asteras-Tripoli-Stats',
#     'https://fbref.com/en/squads/31b8553d/Panserraikos-Stats',
#     'https://fbref.com/en/squads/4a2c27a3/Volos-NFC-Stats',
#     'https://fbref.com/en/squads/2fdb4aef/Olympiacos-Stats',
#     'https://fbref.com/en/squads/0451f017/AO-Kifisia-Stats']},
#   'Nemzeti Bajnokság I': {'2023-2024': ['https://fbref.com/en/squads/cab13f30/Mezokovesd-Stats',
#     'https://fbref.com/en/squads/6611f992/Ferencvaros-Stats',
#     'https://fbref.com/en/squads/e4babb95/Diosgyor-Stats',
#     'https://fbref.com/en/squads/5f778322/Zalaegerszeg-Stats',
#     'https://fbref.com/en/squads/db2b616c/Paks-Stats',
#     'https://fbref.com/en/squads/108607cf/Ujpest-Stats',
#     'https://fbref.com/en/squads/a338349f/Vidi-Stats',
#     'https://fbref.com/en/squads/e56b19e1/Kecskemet-Stats',
#     'https://fbref.com/en/squads/e44db2c6/MTK-Budapest-Stats',
#     'https://fbref.com/en/squads/e24ac92e/Debrecen-Stats',
#     'https://fbref.com/en/squads/6cf72eb0/Puskas-Akademia-Stats',
#     'https://fbref.com/en/squads/2f78fc78/Kisvarda-Stats']},
#   'Indian Super League': {'2023-2024': ['https://fbref.com/en/squads/1ae5d154/Mumbai-City-Stats',
#     'https://fbref.com/en/squads/8f8b1984/Punjab-Stats',
#     'https://fbref.com/en/squads/d6997457/Bengaluru-Stats',
#     'https://fbref.com/en/squads/5c7eb1c7/Mohun-Bagan-Stats',
#     'https://fbref.com/en/squads/366f89ff/East-Bengal-Stats',
#     'https://fbref.com/en/squads/6f0be699/Chennaiyin-Stats',
#     'https://fbref.com/en/squads/238b245d/Odisha-Stats',
#     'https://fbref.com/en/squads/abe09747/Jamshedpur-Stats',
#     'https://fbref.com/en/squads/142886c3/NorthEast-United-Stats',
#     'https://fbref.com/en/squads/dd6945f1/Hyderabad-FC-Stats',
#     'https://fbref.com/en/squads/3249478a/Goa-Stats',
#     'https://fbref.com/en/squads/38c56c1f/Kerala-Blasters-Stats']},
#   'I-League': {'2023-2024': ['https://fbref.com/en/squads/472a48f2/Mohammedan-Stats',
#     'https://fbref.com/en/squads/11d4e726/Namdhari-FC-Stats',
#     'https://fbref.com/en/squads/3a030a2c/Sreenidi-Deccan-FC-Stats',
#     'https://fbref.com/en/squads/d344b030/Real-Kashmir-Stats',
#     'https://fbref.com/en/squads/2a38baa5/NEROCA-Stats',
#     'https://fbref.com/en/squads/9a1cbee5/TRAU-FC-Stats',
#     'https://fbref.com/en/squads/5ae2e6b4/Shillong-Lajong-Stats',
#     'https://fbref.com/en/squads/db891982/Gokulam-Kerala-Stats',
#     'https://fbref.com/en/squads/89d54d32/Churchill-Brothers-Stats',
#     'https://fbref.com/en/squads/8bbd7a4d/Rajasthan-United-FC-Stats',
#     'https://fbref.com/en/squads/9b490f51/Inter-Kashi-Stats',
#     'https://fbref.com/en/squads/bdf24fcf/Delhi-FC-Stats',
#     'https://fbref.com/en/squads/372caef1/Aizawl-Stats']},
#   'Persian Gulf Pro League': {'2023-2024': ['https://fbref.com/en/squads/aa3eb1d3/Foolad-Stats',
#     'https://fbref.com/en/squads/4d1044b8/SorkhPooshan-FC-Stats',
#     'https://fbref.com/en/squads/9fc3b195/Sanat-Naft-Abadan-Stats',
#     'https://fbref.com/en/squads/c659a2f9/Paykan-Stats',
#     'https://fbref.com/en/squads/2c45d10e/Nassaji-Mazandaran-Stats',
#     'https://fbref.com/en/squads/0a2f5c93/Shams-Azar-Qazvin-Stats',
#     'https://fbref.com/en/squads/2f5578dd/Gol-Gohar-Stats',
#     'https://fbref.com/en/squads/dbad5f2c/Esteghlal-Khuzestan-Stats',
#     'https://fbref.com/en/squads/0230c3aa/Tractor-Sazi-Stats',
#     'https://fbref.com/en/squads/e4ec7ab0/Malavan-Stats',
#     'https://fbref.com/en/squads/fe550dbf/Esteghlal-Stats',
#     'https://fbref.com/en/squads/e39cf61a/Sepahan-Stats',
#     'https://fbref.com/en/squads/f8106fc0/Zob-Ahan-Stats',
#     'https://fbref.com/en/squads/95f42e44/Persepolis-Stats',
#     'https://fbref.com/en/squads/971f2157/Mes-Rafsanjan-Stats',
#     'https://fbref.com/en/squads/0e85b362/Aluminium-Arak-Stats']},
#   'J1 League': {'2024': ['https://fbref.com/en/squads/bd03cdde/Cerezo-Osaka-Stats',
#     'https://fbref.com/en/squads/1a921e1f/Shonan-Bellmare-Stats',
#     'https://fbref.com/en/squads/16fa293c/Jubilo-Iwata-Stats',
#     'https://fbref.com/en/squads/858d58b2/Kawasaki-Frontale-Stats',
#     'https://fbref.com/en/squads/e5ce7354/Kyoto-Sanga-Stats',
#     'https://fbref.com/en/squads/f812e711/Urawa-Red-Diamonds-Stats',
#     'https://fbref.com/en/squads/268a561a/Avispa-Fukuoka-Stats',
#     'https://fbref.com/en/squads/33e6936d/Albirex-Niigata-Stats',
#     'https://fbref.com/en/squads/763b322d/Tokyo-Verdy-Stats',
#     'https://fbref.com/en/squads/e2948349/Gamba-Osaka-Stats',
#     'https://fbref.com/en/squads/a33a1d8d/Sanfrecce-Hiroshima-Stats',
#     'https://fbref.com/en/squads/9c584cf2/Nagoya-Grampus-Stats',
#     'https://fbref.com/en/squads/3ded797c/Yokohama-F-Marinos-Stats',
#     'https://fbref.com/en/squads/8867a809/Machida-Zelvia-Stats',
#     'https://fbref.com/en/squads/fac75dc4/Hokkaido-Consadole-Sapporo-Stats',
#     'https://fbref.com/en/squads/dd694b37/Kashima-Antlers-Stats',
#     'https://fbref.com/en/squads/967b10be/FC-Tokyo-Stats',
#     'https://fbref.com/en/squads/b363e21f/Sagan-Tosu-Stats',
#     'https://fbref.com/en/squads/66f38ee7/Vissel-Kobe-Stats',
#     'https://fbref.com/en/squads/aed4d20f/Kashiwa-Reysol-Stats']},
#   'K League 1': {'2024': ['https://fbref.com/en/squads/82d18831/Pohang-Stats',
#     'https://fbref.com/en/squads/8a4abba3/Sangju-Sangmu-Stats',
#     'https://fbref.com/en/squads/ae23a242/Jeonbuk-Stats',
#     'https://fbref.com/en/squads/52874d68/Suwon-FC-Stats',
#     'https://fbref.com/en/squads/ee742bf0/Daegu-Stats',
#     'https://fbref.com/en/squads/c1e93cb7/Incheon-United-Stats',
#     'https://fbref.com/en/squads/79c65a57/Gangwon-Stats',
#     'https://fbref.com/en/squads/2075253c/Daejeon-Citizen-FC-Stats',
#     'https://fbref.com/en/squads/ae306ede/Gwangju-FC-Stats',
#     'https://fbref.com/en/squads/4372a20b/Ulsan-Hyundai-Stats',
#     'https://fbref.com/en/squads/e03e5172/FC-Seoul-Stats',
#     'https://fbref.com/en/squads/e1e9c597/Jeju-United-FC-Stats']},
#   'Saudi Professional League': {'2023-2024': ['https://fbref.com/en/squads/e00d111d/Al-Ittihad-Stats',
#     'https://fbref.com/en/squads/11be4c0a/Al-Ettifaq-Stats',
#     'https://fbref.com/en/squads/9cc24b7e/Al-Fayha-Stats',
#     'https://fbref.com/en/squads/776909d3/Al-Taawoun-Stats',
#     'https://fbref.com/en/squads/0bd39f2b/Al-Khaleej-Stats',
#     'https://fbref.com/en/squads/84bbaea6/Al-Shabab-Stats',
#     'https://fbref.com/en/squads/ad326e5f/Al-Hazem-Stats',
#     'https://fbref.com/en/squads/cb45d9cb/Al-Ahli-Stats',
#     'https://fbref.com/en/squads/972e2539/Al-Hilal-Stats',
#     'https://fbref.com/en/squads/e570aeff/Damac-Stats',
#     'https://fbref.com/en/squads/9e60e560/Al-Raed-Stats',
#     'https://fbref.com/en/squads/769d9b07/Al-Fateh-Stats',
#     'https://fbref.com/en/squads/928d3821/Al-Wehda-Stats',
#     'https://fbref.com/en/squads/3249996d/Al-Okhdood-SC-Stats',
#     'https://fbref.com/en/squads/9892d3af/Abha-Stats',
#     'https://fbref.com/en/squads/8a84803a/Al-Taee-Stats',
#     'https://fbref.com/en/squads/6baef27f/Al-Nassr-Stats',
#     'https://fbref.com/en/squads/114f7a81/Al-Riyadh-SC-Stats']},
#   'Liga MX': {'2023-2024': ['https://fbref.com/en/squads/c3352ce7/Queretaro-Stats',
#     'https://fbref.com/en/squads/5d274ee4/Atletico-Stats',
#     'https://fbref.com/en/squads/03b65ba9/Santos-Laguna-Stats',
#     'https://fbref.com/en/squads/c02b0f7a/Guadalajara-Stats',
#     'https://fbref.com/en/squads/7c76bc53/Atlas-Stats',
#     'https://fbref.com/en/squads/dd5ca9bd/Monterrey-Stats',
#     'https://fbref.com/en/squads/18d3c3a3/America-Stats',
#     'https://fbref.com/en/squads/fd7dad55/Leon-Stats',
#     'https://fbref.com/en/squads/a42ddf2f/Tijuana-Stats',
#     'https://fbref.com/en/squads/c9d59c6c/Pumas-UNAM-Stats',
#     'https://fbref.com/en/squads/73fd2313/Puebla-Stats',
#     'https://fbref.com/en/squads/44b88a4e/Toluca-Stats',
#     'https://fbref.com/en/squads/752db496/Necaxa-Stats',
#     'https://fbref.com/en/squads/d9e1bd51/UANL-Stats',
#     'https://fbref.com/en/squads/29bff345/FC-Juarez-Stats',
#     'https://fbref.com/en/squads/f0297c23/Mazatlan-Stats',
#     'https://fbref.com/en/squads/1be8d2e3/Pachuca-Stats',
#     'https://fbref.com/en/squads/632f1838/Cruz-Azul-Stats']},
#   'Eredivisie': {'2023-2024': ['https://fbref.com/en/squads/e3db180b/Zwolle-Stats',
#     'https://fbref.com/en/squads/3986b791/AZ-Alkmaar-Stats',
#     'https://fbref.com/en/squads/19c3f8c4/Ajax-Stats',
#     'https://fbref.com/en/squads/bd08295c/Fortuna-Sittard-Stats',
#     'https://fbref.com/en/squads/146a68ce/Sparta-Rotterdam-Stats',
#     'https://fbref.com/en/squads/2b41acb5/Almere-City-Stats',
#     'https://fbref.com/en/squads/2a428619/Utrecht-Stats',
#     'https://fbref.com/en/squads/bb14adb3/RKC-Waalwijk-Stats',
#     'https://fbref.com/en/squads/740cb7d4/Excelsior-Stats',
#     'https://fbref.com/en/squads/e33d6108/Go-Ahead-Eagles-Stats',
#     'https://fbref.com/en/squads/c882b88e/Heracles-Almelo-Stats',
#     'https://fbref.com/en/squads/e334d850/PSV-Eindhoven-Stats',
#     'https://fbref.com/en/squads/209d7fa2/Vitesse-Stats',
#     'https://fbref.com/en/squads/fc629994/NEC-Nijmegen-Stats',
#     'https://fbref.com/en/squads/193ff7aa/Heerenveen-Stats',
#     'https://fbref.com/en/squads/8783f4ee/Volendam-Stats',
#     'https://fbref.com/en/squads/a1f721d3/Twente-Stats',
#     'https://fbref.com/en/squads/fb4ca611/Feyenoord-Stats']},
#   'Eliteserien': {'2024': ['https://fbref.com/en/squads/f4bbcd04/Haugesund-Stats',
#     'https://fbref.com/en/squads/a5b8480c/Sandefjord-Stats',
#     'https://fbref.com/en/squads/47b3e736/Sarpsborg-08-Stats',
#     'https://fbref.com/en/squads/aeae4fe1/Brann-Stats',
#     'https://fbref.com/en/squads/3b5f520f/Fredrikstad-Stats',
#     'https://fbref.com/en/squads/0b26f976/Viking-Stats',
#     'https://fbref.com/en/squads/a3ee587a/Tromso-Stats',
#     'https://fbref.com/en/squads/924759ab/Lillestrom-Stats',
#     'https://fbref.com/en/squads/6b5edf57/KFUM-Oslo-Stats',
#     'https://fbref.com/en/squads/b70ec3fa/Odd-Stats',
#     'https://fbref.com/en/squads/9b8e2689/HamKam-Stats',
#     'https://fbref.com/en/squads/c2ccd8f5/Kristiansund-Stats',
#     'https://fbref.com/en/squads/90e37d3a/Rosenborg-Stats',
#     'https://fbref.com/en/squads/90eb0dcc/Stromsgodset-Stats',
#     'https://fbref.com/en/squads/d86248bd/BodoGlimt-Stats',
#     'https://fbref.com/en/squads/174bd5a0/Molde-Stats']},
#   'Paraguayan Primera División': {'2024': ['https://fbref.com/en/squads/4d4fc0b8/Club-Olimpia-Stats',
#     'https://fbref.com/en/squads/ebdc0225/2-de-Mayo-Stats',
#     'https://fbref.com/en/squads/6c3c25bd/Guarani-Stats',
#     'https://fbref.com/en/squads/be1ec8eb/Sportivo-Ameliano-Stats',
#     'https://fbref.com/en/squads/f2769f46/Tacuary-Stats',
#     'https://fbref.com/en/squads/350ce469/Sportivo-Trinidense-Stats',
#     'https://fbref.com/en/squads/e4cd6f9a/Cerro-Porteno-Stats',
#     'https://fbref.com/en/squads/264fce29/Nacional-Asuncion-Stats',
#     'https://fbref.com/en/squads/789c2535/Club-General-Caballero-JLM-Stats',
#     'https://fbref.com/en/squads/d7e6c419/Sportivo-Luqueno-Stats',
#     'https://fbref.com/en/squads/ae107695/Libertad-Stats',
#     'https://fbref.com/en/squads/e58fd7d6/Club-Sol-de-America-Stats']},
#   'Liga 1 de Fútbol Profesional': {'2024': ['https://fbref.com/en/squads/59cf5fee/Comerciantes-Unidos-Stats',
#     'https://fbref.com/en/squads/87ffd947/Melgar-Stats',
#     'https://fbref.com/en/squads/d4f8af71/Cusco-Stats',
#     'https://fbref.com/en/squads/56762359/CDC-Santa-Rosa-Stats',
#     'https://fbref.com/en/squads/0c2512a2/Sport-Boys-Stats',
#     'https://fbref.com/en/squads/0beae1a9/Carlos-A-Mannucci-Stats',
#     'https://fbref.com/en/squads/e71b53ba/Alianza-Atletico-Stats',
#     'https://fbref.com/en/squads/78987e91/Asociacion-Deportiva-Tarma-Stats',
#     'https://fbref.com/en/squads/d1077778/Atletico-Grau-Stats',
#     'https://fbref.com/en/squads/f4afe835/Union-Comercio-Stats',
#     'https://fbref.com/en/squads/8917b8a9/Sporting-Cristal-Stats',
#     'https://fbref.com/en/squads/4271353d/Deportivo-Garcilaso-Stats',
#     'https://fbref.com/en/squads/d7ba2e36/Sport-Huancayo-Stats',
#     'https://fbref.com/en/squads/e4108102/Universitario-Stats',
#     'https://fbref.com/en/squads/cdbccdc1/Alianza-Lima-Stats',
#     'https://fbref.com/en/squads/adf57493/Cienciano-Stats',
#     'https://fbref.com/en/squads/d1f6a4fe/Universidad-Cesar-Vallejo-Stats',
#     'https://fbref.com/en/squads/afccbca8/Universidad-Tecnica-de-Cajamarca-Stats']},
#   'Ekstraklasa': {'2023-2024': ['https://fbref.com/en/squads/3b58a049/Radomiak-Radom-Stats',
#     'https://fbref.com/en/squads/eae6c5ae/Korona-Kielce-Stats',
#     'https://fbref.com/en/squads/eb547ac5/Warta-Poznan-Stats',
#     'https://fbref.com/en/squads/a73408a7/Legia-Warsaw-Stats',
#     'https://fbref.com/en/squads/8a3f95b9/Pogon-Szczecin-Stats',
#     'https://fbref.com/en/squads/cbfe68b7/Puszcza-Niepolomice-Stats',
#     'https://fbref.com/en/squads/6e7c9b0b/Cracovia-Stats',
#     'https://fbref.com/en/squads/d2f21b23/Gornik-Zabrze-Stats',
#     'https://fbref.com/en/squads/ad2649a5/Piast-Gliwice-Stats',
#     'https://fbref.com/en/squads/c39b0fab/Ruch-Chorzow-Stats',
#     'https://fbref.com/en/squads/7211a410/Lodzki-KS-Stats',
#     'https://fbref.com/en/squads/7ed0e406/Stal-Mielec-Stats',
#     'https://fbref.com/en/squads/4f7b798d/Jagiellonia-Stats',
#     'https://fbref.com/en/squads/2232debd/Widzew-Lodz-Stats',
#     'https://fbref.com/en/squads/e0b3aa47/RKS-Rakow-Stats',
#     'https://fbref.com/en/squads/3458af25/Zaglebie-Lubin-Stats',
#     'https://fbref.com/en/squads/fdba14df/Lech-Poznan-Stats',
#     'https://fbref.com/en/squads/c582b57f/Slask-Wroclaw-Stats']},
#   'Primeira Liga': {'2023-2024': ['https://fbref.com/en/squads/eea856da/Rio-Ave-Stats',
#     'https://fbref.com/en/squads/6a329209/Gil-Vicente-FC-Stats',
#     'https://fbref.com/en/squads/a549d6c6/Portimonense-Stats',
#     'https://fbref.com/en/squads/489c9cd9/Farense-Stats',
#     'https://fbref.com/en/squads/69d84c29/Braga-Stats',
#     'https://fbref.com/en/squads/e4502862/Moreirense-Stats',
#     'https://fbref.com/en/squads/0cb9f756/Estrela-Stats',
#     'https://fbref.com/en/squads/37b7e9e2/Boavista-Stats',
#     'https://fbref.com/en/squads/0d36ddd4/Arouca-Stats',
#     'https://fbref.com/en/squads/00c41b75/Estoril-Stats',
#     'https://fbref.com/en/squads/b9daacef/Vizela-Stats',
#     'https://fbref.com/en/squads/bf4e8a13/Chaves-Stats',
#     'https://fbref.com/en/squads/5e876ee6/Porto-Stats',
#     'https://fbref.com/en/squads/2de656d5/Famalicao-Stats',
#     'https://fbref.com/en/squads/a77c513e/Benfica-Stats',
#     'https://fbref.com/en/squads/3f319bc9/Vitoria-Guimaraes-Stats',
#     'https://fbref.com/en/squads/13dc44fd/Sporting-CP-Stats',
#     'https://fbref.com/en/squads/b20a2b76/Casa-Pia-Stats']},
#   'Liga I': {'2023-2024': ['https://fbref.com/en/squads/8e23de35/FC-U-Craiova-Stats',
#     'https://fbref.com/en/squads/86edb46e/Otelul-Galati-Stats',
#     'https://fbref.com/en/squads/099e0a8b/Rapid-Bucuresti-Stats',
#     'https://fbref.com/en/squads/aba482e2/Universitatea-Cluj-Stats',
#     'https://fbref.com/en/squads/c12c3ccf/Politehnica-Iasi-Stats',
#     'https://fbref.com/en/squads/43886f90/Farul-Constanta-Stats',
#     'https://fbref.com/en/squads/d921c99f/Botosani-Stats',
#     'https://fbref.com/en/squads/aed59852/FCSB-Stats',
#     'https://fbref.com/en/squads/d7e82505/Hermannstadt-Stats',
#     'https://fbref.com/en/squads/a862ea1d/UTA-Arad-Stats',
#     'https://fbref.com/en/squads/4f30dd8b/Petrolul-Ploiesti-Stats',
#     'https://fbref.com/en/squads/4aee1804/Sepsi-Sfantu-Gheorghe-Stats',
#     'https://fbref.com/en/squads/34078b64/Voluntari-Stats',
#     'https://fbref.com/en/squads/4472d406/Dinamo-Bucuresti-Stats',
#     'https://fbref.com/en/squads/ff04e205/CFR-Cluj-Stats',
#     'https://fbref.com/en/squads/1eebf7c3/CS-Universitatea-Craiova-Stats']},
#   'South African Premier Division': {'2023-2024': ['https://fbref.com/en/squads/97d80fef/Mamelodi-Sundowns-Stats',
#     'https://fbref.com/en/squads/417af3f7/TS-Galaxy-Stats',
#     'https://fbref.com/en/squads/2898ec06/Kaizer-Chiefs-Stats',
#     'https://fbref.com/en/squads/09ec62b7/Chippa-United-Stats',
#     'https://fbref.com/en/squads/dd0a9674/Moroka-Swallows-Stats',
# ...
#     'https://fbref.com/en/squads/8efa4cdf/Barrow-Stats',
#     'https://fbref.com/en/squads/0cd8eef2/Crawley-Town-Stats',
#     'https://fbref.com/en/squads/f1eb9593/Forest-Green-Rovers-Stats',
#     'https://fbref.com/en/squads/7ef53dcf/Sutton-United-Stats',
#     'https://fbref.com/en/squads/22327064/Tranmere-Rovers-Stats',
#     'https://fbref.com/en/squads/f13a527f/Crewe-Alexandra-Stats',
#     'https://fbref.com/en/squads/13cb8449/Mansfield-Town-Stats',
#     'https://fbref.com/en/squads/802d1b47/Harrogate-Stats',
#     'https://fbref.com/en/squads/4cefb8c7/Salford-City-Stats',
#     'https://fbref.com/en/squads/b17b8146/Colchester-United-Stats',
#     'https://fbref.com/en/squads/03d10d77/Doncaster-Rovers-Stats',
#     'https://fbref.com/en/squads/1b295b25/Swindon-Town-Stats']},
#   'National League': {'2023-2024': ['https://fbref.com/en/squads/8550eb99/Boreham-Wood-Stats',
#     'https://fbref.com/en/squads/2b9f86b0/Southend-United-Stats',
#     'https://fbref.com/en/squads/e272e7a8/York-City-Stats',
#     'https://fbref.com/en/squads/60d44c62/Fylde-Stats',
#     'https://fbref.com/en/squads/2e91bf26/Barnet-Stats',
#     'https://fbref.com/en/squads/6a9477ca/Bromley-Stats',
#     'https://fbref.com/en/squads/a8290768/Aldershot-Town-Stats',
#     'https://fbref.com/en/squads/250e0f45/Gateshead-Stats',
#     'https://fbref.com/en/squads/38154f92/FC-Halifax-Town-Stats',
#     'https://fbref.com/en/squads/2af58c3d/Hartlepool-United-Stats',
#     'https://fbref.com/en/squads/c30e88bc/Woking-Stats',
#     'https://fbref.com/en/squads/9f1a0d0f/Ebbsfleet-United-Stats',
#     'https://fbref.com/en/squads/962bc612/Eastleigh-Stats',
#     'https://fbref.com/en/squads/4a04a02b/Oldham-Athletic-Stats',
#     'https://fbref.com/en/squads/2a0a34ae/Oxford-City-Stats',
#     'https://fbref.com/en/squads/fa7569e4/Kidderminster-Stats',
#     'https://fbref.com/en/squads/ce786972/Chesterfield-Stats',
#     'https://fbref.com/en/squads/9e85547f/Solihull-Moors-Stats',
#     'https://fbref.com/en/squads/4db00b00/Dagenham-and-Redbridge-Stats',
#     'https://fbref.com/en/squads/7cf2360b/Maidenhead-United-Stats',
#     'https://fbref.com/en/squads/51e48db2/Rochdale-Stats',
#     'https://fbref.com/en/squads/6598bf6b/Wealdstone-Stats',
#     'https://fbref.com/en/squads/9ac0ab8c/Dorking-Wand-Stats',
#     'https://fbref.com/en/squads/b30f94be/Altrincham-Stats']}},
#  'F': {'DFB-Pokal Frauen': {'2023-2024': []},
#   'NWSL Challenge Cup': {'2024': []},
#   "FA Women's Super League": {'2023-2024': ['https://fbref.com/en/squads/53157aa8/Aston-Villa-Women-Stats',
#     'https://fbref.com/en/squads/411b1108/Arsenal-Women-Stats',
#     'https://fbref.com/en/squads/52d65cea/West-Ham-United-Women-Stats',
#     'https://fbref.com/en/squads/9ce68f8a/Manchester-City-Women-Stats',
#     'https://fbref.com/en/squads/c4989550/Everton-Women-Stats',
#     'https://fbref.com/en/squads/fa2752bc/Brighton-and-Hove-Albion-Women-Stats',
#     'https://fbref.com/en/squads/41916f68/Bristol-City-Women-Stats',
#     'https://fbref.com/en/squads/00f74a56/Liverpool-Women-Stats',
#     'https://fbref.com/en/squads/e8e4577c/Tottenham-Women-Stats',
#     'https://fbref.com/en/squads/0bbd83f6/Manchester-United-Women-Stats',
#     'https://fbref.com/en/squads/a6a4e67d/Chelsea-Women-Stats',
#     'https://fbref.com/en/squads/23bce84e/Leicester-City-Women-Stats']},
#   'Liga F': {'2023-2024': ['https://fbref.com/en/squads/3fb163d6/Granada-Women-Stats',
#     'https://fbref.com/en/squads/0f4738a8/Levante-Women-Stats',
#     'https://fbref.com/en/squads/94929c05/Athletic-Club-Women-Stats',
#     'https://fbref.com/en/squads/753b93a5/Levante-Las-Planas-Stats',
#     'https://fbref.com/en/squads/74142337/Real-Betis-Women-Stats',
#     'https://fbref.com/en/squads/215d9026/Sevilla-Women-Stats',
#     'https://fbref.com/en/squads/c21f25d3/Real-Sociedad-Women-Stats',
#     'https://fbref.com/en/squads/4c088abe/UDG-Tenerife-Stats',
#     'https://fbref.com/en/squads/f96ff499/Valencia-Women-Stats',
#     'https://fbref.com/en/squads/89818574/Madrid-CFF-Stats',
#     'https://fbref.com/en/squads/27acb0af/Sporting-de-Huelva-Stats',
#     'https://fbref.com/en/squads/e4f27ff1/Eibar-Women-Stats',
#     'https://fbref.com/en/squads/15f49df1/Barcelona-Women-Stats',
#     'https://fbref.com/en/squads/54582b93/Real-Madrid-Women-Stats',
#     'https://fbref.com/en/squads/b56c2667/Atletico-Madrid-Women-Stats',
#     'https://fbref.com/en/squads/7a7bef84/Villarreal-Women-Stats']},
#   'Championnat de France de Football Féminin': {'2023-2024': ['https://fbref.com/en/squads/abc4f6d7/Guingamp-Women-Stats',
#     'https://fbref.com/en/squads/7bbdea71/Montpellier-Women-Stats',
#     'https://fbref.com/en/squads/7f2012ad/Lyon-Women-Stats',
#     'https://fbref.com/en/squads/28d9b675/Paris-FC-Women-Stats',
#     'https://fbref.com/en/squads/c57b7254/Le-Havre-Women-Stats',
#     'https://fbref.com/en/squads/69dee2b0/Bordeaux-Women-Stats',
#     'https://fbref.com/en/squads/c1a6475c/Saint-Etienne-Women-Stats',
#     'https://fbref.com/en/squads/80595417/Paris-Saint-Germain-Women-Stats',
#     'https://fbref.com/en/squads/6f14046a/Lille-Women-Stats',
#     'https://fbref.com/en/squads/68f9fd31/Dijon-Women-Stats',
#     'https://fbref.com/en/squads/4fcc2996/Fleury-Stats',
#     'https://fbref.com/en/squads/e3696882/Stade-de-Reims-Women-Stats']},
#   'Frauen-Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/7adbf480/Werder-Bremen-Women-Stats',
#     'https://fbref.com/en/squads/51ec22be/Bayern-Munich-Women-Stats',
#     'https://fbref.com/en/squads/97b7c0e8/Eintracht-Frankfurt-Women-Stats',
#     'https://fbref.com/en/squads/becc1dd0/Essen-Stats',
#     'https://fbref.com/en/squads/a1393014/Wolfsburg-Women-Stats',
#     'https://fbref.com/en/squads/c6d4860a/Bayer-Leverkusen-Women-Stats',
#     'https://fbref.com/en/squads/b4de690d/Freiburg-Women-Stats',
#     'https://fbref.com/en/squads/88ddc98e/Koln-Women-Stats',
#     'https://fbref.com/en/squads/0580d9a9/MSV-Duisburg-Women-Stats',
#     'https://fbref.com/en/squads/87705c62/Hoffenheim-Women-Stats',
#     'https://fbref.com/en/squads/9224f982/RB-Leipzig-Women-Stats',
#     'https://fbref.com/en/squads/b6d83168/1-FC-Nurnberg-Women-Stats']},
#   'Serie A': {'2023-2024': ['https://fbref.com/en/squads/756c9acb/FC-Como-Women-Stats',
#     'https://fbref.com/en/squads/02f8d026/AS-Roma-Stats',
#     'https://fbref.com/en/squads/58e367c3/Sampdoria-Women-Stats',
#     'https://fbref.com/en/squads/c99ff6e5/Fiorentina-Women-Stats',
#     'https://fbref.com/en/squads/54da9a57/Milan-Women-Stats',
#     'https://fbref.com/en/squads/828ce826/Napoli-Women-Stats',
#     'https://fbref.com/en/squads/06d05f19/Internazionale-Women-Stats',
#     'https://fbref.com/en/squads/a8e83f23/Sassuolo-Women-Stats',
#     'https://fbref.com/en/squads/9f18ced7/ASD-Calcio-Pomigliano-Stats',
#     'https://fbref.com/en/squads/613577b8/Juventus-Women-Stats']},
#   'A-League Women': {'2023-2024': ['https://fbref.com/en/squads/bc52ac89/Wellington-Phoenix-FC-Stats',
#     'https://fbref.com/en/squads/bae78cfe/Perth-Glory-Women-Stats',
#     'https://fbref.com/en/squads/772ed712/Adelaide-United-Women-Stats',
#     'https://fbref.com/en/squads/0a911f26/Western-United-Women-Stats',
#     'https://fbref.com/en/squads/a2fa3506/Canberra-United-Stats',
#     'https://fbref.com/en/squads/5903e501/Sydney-FC-Women-Stats',
#     'https://fbref.com/en/squads/25b31403/Western-Sydney-Wanderers-Women-Stats',
#     'https://fbref.com/en/squads/acd7ce24/Newcastle-Jets-Women-Stats',
#     'https://fbref.com/en/squads/4f6d7ee7/Melbourne-Victory-Women-Stats',
#     'https://fbref.com/en/squads/6082332e/Melbourne-City-Women-Stats',
#     'https://fbref.com/en/squads/f60413f7/Brisbane-Roar-Women-Stats',
#     'https://fbref.com/en/squads/debae7df/Central-Coast-Mariners-Women-Stats']},
#   'ÖFB Frauen-Bundesliga': {'2023-2024': ['https://fbref.com/en/squads/f2370380/Wacker-Innsbruck-Women-Stats',
#     'https://fbref.com/en/squads/60942bd8/Landhaus-Stats',
#     'https://fbref.com/en/squads/424e506f/First-Vienna-FC-Stats',
#     'https://fbref.com/en/squads/117f88e3/FC-Bergheim-Stats',
#     'https://fbref.com/en/squads/3d377a8c/St-Polten-Women-Stats',
#     'https://fbref.com/en/squads/e21816f2/SV-Neulengbach-Stats',
#     'https://fbref.com/en/squads/b8076337/SPG-FC-LustenauFC-Dornbirn-Ladies-Stats',
#     'https://fbref.com/en/squads/828e25c7/Vorderland-Stats',
#     'https://fbref.com/en/squads/f59ec0ea/SPG-UNION-KleinmunchenBW-Linz-Stats',
#     'https://fbref.com/en/squads/07787bf7/Sturm-Graz-Women-Stats']},
#   "Belgian Women's Super League": {'2023-2024': ['https://fbref.com/en/squads/231a3620/Anderlecht-Women-Stats',
#     'https://fbref.com/en/squads/5cc94039/KAA-La-Gantoise-Stats',
#     'https://fbref.com/en/squads/3a282a27/Charleroi-Stats',
#     'https://fbref.com/en/squads/668e0951/Zulte-Waregem-Stats',
#     'https://fbref.com/en/squads/696ced1d/OH-Leuven-Women-Stats',
#     'https://fbref.com/en/squads/261c5544/Standard-Liege-Women-Stats',
#     'https://fbref.com/en/squads/07664737/Club-Brugge-Women-Stats',
#     'https://fbref.com/en/squads/eac05419/DVL-Zonhoven-Stats',
#     'https://fbref.com/en/squads/a172ed0a/Yellow-Red-KV-Mechelen-Stats',
#     'https://fbref.com/en/squads/a697eb08/White-Star-Stats']},
#   'Brasileirão Feminino Série A1': {'2024': ['https://fbref.com/en/squads/1bf3f807/Sao-Paulo-Women-Stats',
#     'https://fbref.com/en/squads/f3186648/Flamengo-Women-Stats',
#     'https://fbref.com/en/squads/750147f8/America-MG-Women-Stats',
#     'https://fbref.com/en/squads/289b0441/Botafogo-FR-Stats',
#     'https://fbref.com/en/squads/e6079b11/Gremio-FBPA-Stats',
#     'https://fbref.com/en/squads/bd614ad8/Fluminense-FC-Stats',
#     'https://fbref.com/en/squads/92946864/Santos-FC-Stats',
#     'https://fbref.com/en/squads/cbecab54/Avai-Women-Stats',
#     'https://fbref.com/en/squads/9a347f63/Real-Brasilia-FC-Stats',
#     'https://fbref.com/en/squads/fe38f57e/CA-Mineiro-Stats',
#     'https://fbref.com/en/squads/a9d9931b/Palmeiras-Women-Stats',
#     'https://fbref.com/en/squads/a42a6f49/Red-Bull-Bragantino-Women-Stats',
#     'https://fbref.com/en/squads/bc0fa202/Cruzeiro-EC-Stats',
#     'https://fbref.com/en/squads/4bb1ba5a/Ferroviaria-Stats',
#     'https://fbref.com/en/squads/32ee23ab/Internacional-Women-Stats',
#     'https://fbref.com/en/squads/9cdc3b24/Corinthians-Women-Stats']},
#   "Danish Women's League": {'2023-2024': ['https://fbref.com/en/squads/177773d3/2023-2024/Naestved-Stats',
#     'https://fbref.com/en/squads/43155d0b/2023-2024/Osterbro-IF-Stats',
#     'https://fbref.com/en/squads/27a26d62/Thy-ThistedQ-Stats',
#     'https://fbref.com/en/squads/c79fd673/2023-2024/B93-Kobenhavn-Stats',
#     'https://fbref.com/en/squads/40e6d8bf/KoldingQ-Stats',
#     'https://fbref.com/en/squads/3c94e2df/Fortuna-Hjorring-Stats',
#     'https://fbref.com/en/squads/cc759c71/Aalborg-BK-Stats',
#     'https://fbref.com/en/squads/c68f3074/Aarhus-GF-Stats',
#     'https://fbref.com/en/squads/b00041f6/HB-Koge-Stats',
#     'https://fbref.com/en/squads/ae395858/FC-Nordsjaelland-Stats',
#     'https://fbref.com/en/squads/4b23c2af/Brondby-Women-Stats',
#     'https://fbref.com/en/squads/d65d277e/2023-2024/Odense-Q-Stats']},
#   'Women Empowerment League': {'2023-2024': ['https://fbref.com/en/squads/f23bc2a0/JEF-United-Chiba-Women-Stats',
#     'https://fbref.com/en/squads/037f2fd4/Cerezo-Osaka-Ladies-Stats',
#     'https://fbref.com/en/squads/70b59cba/AS-Elfen-Saitama-Stats',
#     'https://fbref.com/en/squads/c673cb9f/Urawa-Reds-Ladies-Stats',
#     'https://fbref.com/en/squads/5ec065a5/Vegalta-Sendai-Women-Stats',
#     'https://fbref.com/en/squads/c5721d03/Omiya-Ardija-Women-Stats',
#     'https://fbref.com/en/squads/6437f492/Nagano-Parceiro-Ladies-Stats',
#     'https://fbref.com/en/squads/6e29d17e/Nojima-Stella-Stats',
#     'https://fbref.com/en/squads/de0a0838/Albirex-Niigata-Women-Stats',
#     'https://fbref.com/en/squads/64b65dcf/Sanfrecce-Hiroshima-Regina-Stats',
#     'https://fbref.com/en/squads/71dc1b0b/Kobe-Leonessa-Stats',
#     'https://fbref.com/en/squads/22056158/NTV-Beleza-Stats']},
#   'Eredivisie Vrouwen': {'2023-2024': ['https://fbref.com/en/squads/0db64b70/ADO-Den-Haag-Women-Stats',
#     'https://fbref.com/en/squads/e04b1b89/Twente-Women-Stats',
#     'https://fbref.com/en/squads/27a6967d/FC-Utrecht-Stats',
#     'https://fbref.com/en/squads/e5cdaa81/VV-Alkmaar-Stats',
#     'https://fbref.com/en/squads/c3139207/Zwolle-Women-Stats',
#     'https://fbref.com/en/squads/2bb84f84/Telstar-1963-Stats',
#     'https://fbref.com/en/squads/38d7847d/Feyenoord-Vrouwen-Stats',
#     'https://fbref.com/en/squads/d7b02abb/ExcelsiorBarendrecht-Women-Stats',
#     'https://fbref.com/en/squads/4573a712/Ajax-Women-Stats',
#     'https://fbref.com/en/squads/93d5086f/Heerenveen-Women-Stats',
#     'https://fbref.com/en/squads/9522e7b4/PSV-Vrouwen-Stats',
#     'https://fbref.com/en/squads/0daf5e56/Fortuna-Sittard-Stats']},
#   'Toppserien': {'2024': ['https://fbref.com/en/squads/2a099e55/Roa-Stats',
#     'https://fbref.com/en/squads/a29db84b/Arna-Bjornar-Stats',
#     'https://fbref.com/en/squads/c1c51bdf/Valerenga-Women-Stats',
#     'https://fbref.com/en/squads/ea339fbc/Brann-Stats',
#     'https://fbref.com/en/squads/8cf14206/Rosenborg-Women-Stats',
#     'https://fbref.com/en/squads/ca6492f2/LSK-Kvinner-Stats',
#     'https://fbref.com/en/squads/f11f75c5/Stabaek-Women-Stats',
#     'https://fbref.com/en/squads/734efbe5/Lyn-Women-Stats',
#     'https://fbref.com/en/squads/15c636dc/Kolbotn-Stats',
#     'https://fbref.com/en/squads/230c1c49/Asane-Fotball-Damer-Stats']},
#   "Swiss Women's Super League": {'2023-2024': ['https://fbref.com/en/squads/6e7892af/BSC-YB-Frauen-Stats',
#     'https://fbref.com/en/squads/01dccd92/2023-2024/FC-Wil-1900-Stats',
#     'https://fbref.com/en/squads/e83b563b/Servette-Stats',
#     'https://fbref.com/en/squads/c23b8fbb/2023-2024/FC-Sion-Stats',
#     'https://fbref.com/en/squads/4839a4f1/Grasshopper-Women-Stats',
#     'https://fbref.com/en/squads/389a13b7/Basel-Women-Stats',
#     'https://fbref.com/en/squads/6532abfd/St-Gallen-Staad-Stats',
#     'https://fbref.com/en/squads/b31a2b9e/FC-Rapperswil-Jona-Stats',
#     'https://fbref.com/en/squads/8266975e/Zurich-Women-Stats',
#     'https://fbref.com/en/squads/8639922f/FC-Aarau-Stats',
#     'https://fbref.com/en/squads/74607214/Thun-Berner-Oberland-Stats',
#     'https://fbref.com/en/squads/05ccbeee/FC-Luzern-Frauen-Stats']},
#   'Damallsvenskan': {'2024': ['https://fbref.com/en/squads/10207b7a/Hammarby-Women-Stats',
#     'https://fbref.com/en/squads/6e6b8b3f/Djurgarden-Women-Stats',
#     'https://fbref.com/en/squads/661daef2/AIK-Fotboll-Dam-Stats',
#     'https://fbref.com/en/squads/2972399d/Linkoping-Stats',
#     'https://fbref.com/en/squads/a1979431/Vittsjo-Stats',
#     'https://fbref.com/en/squads/89f584e1/BK-Hacken-Women-Stats',
#     'https://fbref.com/en/squads/c5703518/Vaxjo-Stats',
#     'https://fbref.com/en/squads/9ec14616/Kristianstad-Stats',
#     'https://fbref.com/en/squads/a2c4c17a/Rosengard-Stats',
#     'https://fbref.com/en/squads/892e1bd7/IF-Brommapojkarna-Stats',
#     'https://fbref.com/en/squads/a5e92def/Pitea-Stats',
#     'https://fbref.com/en/squads/3f1d88b4/IFK-Norrkoping-DFK-Stats',
#     'https://fbref.com/en/squads/9e6fd5fb/KIF-Orebro-Stats',
#     'https://fbref.com/en/squads/b76a85f3/Trelleborgs-FF-Stats']},
#   "National Women's Soccer League": {'2024': ['https://fbref.com/en/squads/231a532f/Bay-FC-Stats',
#     'https://fbref.com/en/squads/d976a235/Chicago-Red-Stars-Stats',
#     'https://fbref.com/en/squads/2a6178ac/Orlando-Pride-Stats',
#     'https://fbref.com/en/squads/257fad2b/Seattle-Reign-FC-Stats',
#     'https://fbref.com/en/squads/e442aad0/Washington-Spirit-Stats',
#     'https://fbref.com/en/squads/e813709a/Houston-Dash-Stats',
#     'https://fbref.com/en/squads/ae38d267/Angel-City-FC-Stats',
#     'https://fbref.com/en/squads/df9a10a1/Portland-Thorns-FC-Stats',
#     'https://fbref.com/en/squads/d4c130bc/Utah-Royals-Stats',
#     'https://fbref.com/en/squads/85c458aa/North-Carolina-Courage-Stats',
#     'https://fbref.com/en/squads/da19ebd1/Racing-Louisville-Stats',
#     'https://fbref.com/en/squads/6f666306/Kansas-City-Current-Stats',
#     'https://fbref.com/en/squads/8e306dc6/Gotham-FC-Stats',
#     'https://fbref.com/en/squads/bf961da0/San-Diego-Wave-Stats']}}}

# %%
   def get_stats_team_table(data,list_not_have,club_name,competition,gk_avncd_info = False,only_std_stats = True):

        ctrl_list = []
        list_std_stats = []
        dict_stats = {}

        stats_list =  ['Standard Stats', 'Miscellaneous Stats', 'Goalkeeping','Playing Time','Possession','Defensive Actions','Advanced Goalkeeping','Shooting','Passing','Pass Types','Goal and Shot Creation']

        if gk_avncd_info == False:
            stats_list.remove('Advanced Goalkeeping')

        dict_stats[club_name] = {}

        try:
            df_std_stats = pd.read_html(data.text, match='Standard Stats')[0]
            df_std_stats.columns = adjust_column(df_std_stats)
            df_std_stats['Club'] = club_name
            df_std_stats['Competition'] = competition

            list_std_stats.append(df_std_stats)
            dict_stats[club_name]['Standard Stats'] = df_std_stats.to_json(orient='records') 

            
            ctrl_list.append('Standard Stats')
        except ValueError as e:
            dict_stats = {}

        
        if only_std_stats == True:
            return dict_stats
        else:
            list_stats = []

            if len(list_not_have) == 0:
                stats_dont_have = set()
            else:
                stats_dont_have = list_not_have

            for stats in stats_list:
                if (stats not in ctrl_list) and (stats not in stats_dont_have) :
                    try:
                        df = pd.read_html(data.text, match=stats)[0]
                        df.columns = adjust_column(df)
                  #      list_stats.append(df)
                        dict_stats[club_name][stats] = df.to_json(orient='records') 

                        ctrl_list.append(stats)
                        #df.columns = list(df.columns)
                    except ValueError as e:
                        stats_dont_have.add(stats)
                        continue
                else:
                    continue
            
            return dict_stats,stats_dont_have

# %%
    def main_get_stats_clubs(gender='All'):

        if gender != 'All':
          json_file = verifica_e_le_json('link_teams_available.json')[gender] #get_competition_coverage_all()
          links_teams_json = {}
          links_teams_json[gender] = json_file
        else:
          links_teams_json = verifica_e_le_json('link_teams_available.json')

        if links_teams_json is None:
            links_teams_json = return_team_links(gender)


        req_num = 0
        final_dict = {}
        clubs_info_list = []
        dont_have_dict = {}


        for gender in links_teams_json.keys():
            final_dict[gender] = {}
            print(gender)
            for comp in links_teams_json[gender].keys():
                comp_name = comp
                dont_have_dict[comp_name] = set()

                final_dict[gender][comp_name] = {}
                for season in links_teams_json[gender][comp_name].keys():
                    current_season = season
 

                    list_links_team = links_teams_json[gender][comp_name][current_season]

                    if len(list_links_team) == 0:
                        continue
                    print(comp_name)

                    for link in list_links_team:

                        list_not_have = dont_have_dict[comp_name]

                        match = re.search(r'/([^/]+)-Stats$', link)
                        ext_texto = match.group(1)
                        nome_clube = ext_texto.replace('-',' ')

                        if req_num <= 20:

                            data = requests.get(link, headers=get_user_agent())
                            req_num += 1

                            if data.status_code in (500,403,404):
                                continue

                            dict_stats,dont_have_list = get_stats_team_table(data,list_not_have,club_name = nome_clube,competition = comp_name,gk_avncd_info = False,only_std_stats = False)
                            dont_have_dict[comp_name] = dont_have_list
                            clubs_info_list.append(dict_stats)
                        
                        else:
                            time.sleep(60)
                            req_num = 0

                            data = requests.get(link, headers=get_user_agent())
                            req_num += 1

                            if data.status_code in (500,403,404):
                                continue

                            dict_stats,dont_have_list = get_stats_team_table(data,list_not_have,club_name = nome_clube,competition = comp_name,gk_avncd_info = False,only_std_stats = False)
                            dont_have_dict[comp_name] = dont_have_list
                            clubs_info_list.append(dict_stats)

                    final_dict[gender][comp_name][season] = clubs_info_list



       # with open('all_stats.json', 'w') as json_file:
      #    json.dump(final_dict, json_file)
            
        return final_dict

# %%
final_dict = main_get_stats_clubs(gender='F')
# Out:
# F
# FA Women's Super League
# Liga F
# Championnat de France de Football Féminin
# Frauen-Bundesliga
# Serie A
# A-League Women
# ÖFB Frauen-Bundesliga
# Belgian Women's Super League
# Brasileirão Feminino Série A1
# Danish Women's League
# Women Empowerment League
# Eredivisie Vrouwen
# Toppserien
# Swiss Women's Super League
# Damallsvenskan
# National Women's Soccer League
